# %%
# Out:
# usage: ipykernel_launcher.py [-h] [--population POPULATION] [--days DAYS]
#                              [--scenario {baseline,sin_control,low_mobility,reduccion_movilidad,vaccination,vacunacion}]
#                              [--params_csv PARAMS_CSV] [--vacc_frac VACC_FRAC]
#                              [--mask_frac MASK_FRAC] [--output_csv OUTPUT_CSV]
#                              [--output_png OUTPUT_PNG] [--cpu]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/Users/peter/Library/Jupyter/runtime/kernel-v34a8686518377f30c4afb0dce40c85a31f29044d7.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:3585: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
